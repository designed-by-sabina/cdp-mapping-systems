# %% [markdown]
# # Web Maps I worked on this semester

# %% [markdown]
# **Mapping Systems Final:**<br>
# Mapping Restaurants closest to the route through Central Park <br>
# https://designed-by-sabina.github.io/mapping_website_restaurants-on-route/
#
#
# **Methods as Practices, Practices as Methods:** <br>
# Mapping Commercial Buildings that can be potentially converted to Residential in Manhattan<br>
#
# **Map 1:** https://designed-by-sabina.github.io/Adaptive-Reuse-and-Conversion-of-Commercial-Buildings/zoning-overview.html<br>
#
# **Map 2:** https://designed-by-sabina.github.io/Adaptive-Reuse-and-Conversion-of-Commercial-Buildings/zoning-and-massing-modifications.html
#
#
# **Computational Design Workflows:**<br>
# Mapping Color Pigments Origins<br>
# https://designed-by-sabina.github.io/computational-design-workflows/<br>
# (Click Dot 4 on navigation tab to skip other canvases)
