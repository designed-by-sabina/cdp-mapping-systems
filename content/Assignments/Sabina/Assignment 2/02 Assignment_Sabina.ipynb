# %% [markdown]
# # My go-to spots to grab a bite on Newbury Street
#
# The geojson file in this folder contains my favorite places on Newbury Street, Boston, MA. It includes one ice cream shop, one bubble tea spot, one coffee shop, and a bunch of restaurants.
#
#
#
# I have found "Active Food Establishment Licenses" data set for Boston at Analyze Boston.
# Here is the link to the set:
# https://data.boston.gov/dataset/active-food-establishment-licenses
#
# Below is a proposed workflow for relating the two data sets:

# %%
Set 1: My go-to spots to grab a bite on Newbury Street
Set 2: Active Food Establishment Licenses
(latitude/longitude + label check workflow)
          │
          
For each favorite spot:
Find the closest record in
Active Food Establishment Licenses
using latitude + longitude
          │
          
Check whether the saved-spot label
shares words with the license
businessname or dbaname
          │
     ┌────┴────┐
        
Location close  Location close,
+ name matches  but name does not match
     │                 │
            
Accept match   Flag for review
     │
          
Join license information
to the saved GeoJSON point
