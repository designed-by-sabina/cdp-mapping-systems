# %% [markdown]
# # Web Map Submission for https://www.metmuseum.org/

# %% [markdown]
# ![My Image](Met_from_web.png)

# %% [markdown]
# *ip_locations.geojson*
#
# content\Assignments\Sabina\Assignment 4\ip_locations.geojson
#
#
#
# *Met_map* Folder
#
# content\Assignments\Sabina\Assignment 4\Met_map
